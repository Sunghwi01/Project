# %%
import pandas as pd
pd.options.display.float_format = '{:.5f}'.format

# %%
import pandas as pd

# %%
p_jae = pd.read_csv('./csv/data/dataset/pastjae.csv', encoding='CP949')

# %%
p_jae['회계년도'] = pd.to_datetime(p_jae['회계년도'])

# %%
p_jae['years']=p_jae['회계년도'].dt.year

# %%
p_jae['회사명']= p_jae['회사명'].str.replace('\(','')
p_jae['회사명']= p_jae['회사명'].str.replace('\)','')
p_jae['회사명']= p_jae['회사명'].str.replace('주','')
# Out:
# <ipython-input-25-64f8d100cf86>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   p_jae['회사명']= p_jae['회사명'].str.replace('\(','')
# <ipython-input-25-64f8d100cf86>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   p_jae['회사명']= p_jae['회사명'].str.replace('\)','')

# %%
p_jae = p_jae.rename(columns={'회사명':'종목명'})

# %%
allPBR = pd.read_csv('./csv/data/dataset/allPBRsang.csv')

# %%
allPBR.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
Low_so = pd.read_csv('./csv/data/dataset/LOW_so.csv')

# %%
Low_so.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
allPBR
# Out:
#            종목명  years  month  상장주식수대비월거래량합계    벤치마크지수     소외주      EPS    PER  \
# 0         서울가스   2019     10       0.039660  0.319719     소외주  10653.0   6.36
# 1          디씨엠   2019     10       0.137197  0.319719     소외주    715.0  17.06
# 2        신영와코루   2019     10       0.138444  0.319719     소외주   3010.0  33.72
# 3           조흥   2019     10       0.142833  0.319719     소외주  13392.0  11.16
# 4         대림통상   2019     10       0.183947  0.319719     소외주      NaN    NaN
# ...        ...    ...    ...            ...       ...     ...      ...    ...
# 40509    대유플러스   2021      6     665.384368  0.743445  소외주가아님      NaN    NaN
# 40510     한전산업   2021      6     731.851445  0.743445  소외주가아님    419.0  30.07
# 40511  한솔로지스틱스   2021      6     745.682778  0.743445  소외주가아님    316.0  14.18
# 40512      쌍방울   2021      6    1207.395281  0.743445  소외주가아님      NaN    NaN
# 40513     대원전선   2021      6    1961.172075  0.743445  소외주가아님     32.0  96.09
#
# ...

# %%
Low_so
# Out:
#         종목명      EPS   PER       BPS   PBR  years  month    업종명  업종월평균PBR  \
# 0    예스코홀딩스   4481.0  9.16  106531.0  0.39   2018      6   서비스업  1.973571
# 1    예스코홀딩스   4481.0  8.77  106531.0  0.37   2018      7   서비스업  1.865000
# 2    예스코홀딩스   4481.0  8.83  106531.0  0.37   2018      8   서비스업  1.832909
# 3    예스코홀딩스   4481.0  9.06  106531.0  0.38   2018      9   서비스업  1.920893
# 4    예스코홀딩스   4481.0  9.08  106531.0  0.38   2018     11   서비스업  1.755088
# ..      ...      ...   ...       ...   ...    ...    ...    ...       ...
# 454    서울가스  10653.0  6.31  188727.0  0.36   2019      9  전기가스업  0.393333
# 455    서울가스  10653.0  6.36  188727.0  0.36   2019     10  전기가스업  0.385556
# 456    서울가스  10653.0  6.74  188727.0  0.38   2019     11  전기가스업  0.394444
# 457    서울가스  10653.0  6.63  188727.0  0.37   2019     12  전기가스업  0.385556
# 458    흥국화재    695.0  4.18   10466.0  0.28   2020      1     보험  0.445833
#
#     LOW P/B  상장주식수대비월거래량합계          거래대금        상장시가총액    벤치마크지수  소외주
# ...

# %%
Low_so_jae = pd.merge(Low_so,p_jae,on=['종목명','years'],how='inner')

# %%
Low_so_jae.columns
# Out:
# Index(['종목명', 'EPS', 'PER', 'BPS', 'PBR', 'years', 'month', '업종명', '업종월평균PBR',
#        'LOW P/B', '상장주식수대비월거래량합계', '거래대금', '상장시가총액', '벤치마크지수', '소외주', '거래소코드',
#        '회계년도', '총자본증가율(IFRS)', '자기자본증가율(IFRS)', '매출액증가율(IFRS)', '순이익증가율(IFRS)',
#        '매출액순이익률(IFRS)', '총자본순이익률(IFRS)', '자기자본순이익률(IFRS)', '자본금순이익률(IFRS)',
#        '유보율(IFRS)', '사내유보율(IFRS)', '자기자본배당률(IFRS)', '배당성향(IFRS)',
#        '자기자본구성비율(IFRS)', '타인자본구성비율(IFRS)', '부채비율(IFRS)', '총자본회전률(IFRS)',
#        '자기자본회전률(IFRS)', '자본금회전률(IFRS)', '타인자본회전률(IFRS)', 'PER(최저)(IFRS)',
#        'PBR(최저)(IFRS)', 'PCR(최저)(IFRS)', 'PSR(최저)(IFRS)'],
#       dtype='object')

# %%
Low_so_jae
# Out:
#           종목명     EPS    PER       BPS   PBR  years  month    업종명  업종월평균PBR  \
# 0      예스코홀딩스  4481.0   9.16  106531.0  0.39   2018      6   서비스업  1.973571
# 1      예스코홀딩스  4481.0   8.77  106531.0  0.37   2018      7   서비스업  1.865000
# 2      예스코홀딩스  4481.0   8.83  106531.0  0.37   2018      8   서비스업  1.832909
# 3      예스코홀딩스  4481.0   9.06  106531.0  0.38   2018      9   서비스업  1.920893
# 4      예스코홀딩스  4481.0   9.08  106531.0  0.38   2018     11   서비스업  1.755088
# ..        ...     ...    ...       ...   ...    ...    ...    ...       ...
# 362      삼정펄프     NaN    NaN   72139.0  0.40   2020      2   종이목재  1.016250
# 363      삼정펄프  1868.0  15.23   73851.0  0.39   2020     10   종이목재  1.016471
# 364  한진중공업홀딩스     NaN    NaN   14433.0  0.27   2018      2  전기가스업  0.477500
# 365  한진중공업홀딩스     NaN    NaN   14433.0  0.25   2018      3  전기가스업  0.468750
# 366  한진중공업홀딩스     NaN    NaN   11219.0  0.38   2018      6  전기가스업  0.528889
#
# ...

# %%
trade_up = pd.read_csv('./csv/data/dataset/trade_upjong.csv')

# %%
trade_up.columns
# Out:
# Index(['종목명', '종목코드', '종가', '대비', '등락률', '시가', '고가', '저가', '거래량', '거래대금',
#        '시가총액', '상장주식수', 'years', 'month', '상장주식수대비거래량', '시가총액대비거래대금', '표준편차',
#        '거래량_합계', '거래량_일평균', '거래대금_합계', '거래대금_일평균', '상장주식수대비월거래량합계', '업종명'],
#       dtype='object')

# %%
trade_up.drop(['종목코드','시가','고가','종가','저가','상장주식수','시가총액대비거래대금','업종명'],axis=1,inplace=True)

# %%
Lstrade= pd.merge(Low_so_jae,trade_up,on=['종목명','years','month'],how='inner')

# %%
Lstrade
# Out:
#           종목명     EPS    PER       BPS   PBR  years  month    업종명  업종월평균PBR  \
# 0      예스코홀딩스  4481.0   9.16  106531.0  0.39   2018      6   서비스업  1.973571
# 1      예스코홀딩스  4481.0   8.77  106531.0  0.37   2018      7   서비스업  1.865000
# 2      예스코홀딩스  4481.0   8.83  106531.0  0.37   2018      8   서비스업  1.832909
# 3      예스코홀딩스  4481.0   9.06  106531.0  0.38   2018      9   서비스업  1.920893
# 4      예스코홀딩스  4481.0   9.08  106531.0  0.38   2018     11   서비스업  1.755088
# ..        ...     ...    ...       ...   ...    ...    ...    ...       ...
# 362      삼정펄프     NaN    NaN   72139.0  0.40   2020      2   종이목재  1.016250
# 363      삼정펄프  1868.0  15.23   73851.0  0.39   2020     10   종이목재  1.016471
# 364  한진중공업홀딩스     NaN    NaN   14433.0  0.27   2018      2  전기가스업  0.477500
# 365  한진중공업홀딩스     NaN    NaN   14433.0  0.25   2018      3  전기가스업  0.468750
# 366  한진중공업홀딩스     NaN    NaN   11219.0  0.38   2018      6  전기가스업  0.528889
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font', family='Malgun Gothic')

# %%
Lstrade.columns
# Out:
# Index(['종목명', 'EPS', 'PER', 'BPS', 'PBR', 'years', 'month', '업종명', '업종월평균PBR',
#        'LOW P/B', '상장주식수대비월거래량합계_x', '거래대금_x', '상장시가총액', '벤치마크지수', '소외주',
#        '거래소코드', '회계년도', '총자본증가율(IFRS)', '자기자본증가율(IFRS)', '매출액증가율(IFRS)',
#        '순이익증가율(IFRS)', '매출액순이익률(IFRS)', '총자본순이익률(IFRS)', '자기자본순이익률(IFRS)',
#        '자본금순이익률(IFRS)', '유보율(IFRS)', '사내유보율(IFRS)', '자기자본배당률(IFRS)',
#        '배당성향(IFRS)', '자기자본구성비율(IFRS)', '타인자본구성비율(IFRS)', '부채비율(IFRS)',
#        '총자본회전률(IFRS)', '자기자본회전률(IFRS)', '자본금회전률(IFRS)', '타인자본회전률(IFRS)',
#        'PER(최저)(IFRS)', 'PBR(최저)(IFRS)', 'PCR(최저)(IFRS)', 'PSR(최저)(IFRS)',
#        '대비', '등락률', '거래량', '거래대금_y', '시가총액', '상장주식수대비거래량', '표준편차', '거래량_합계',
#        '거래량_일평균', '거래대금_합계', '거래대금_일평균', '상장주식수대비월거래량합계_y'],
#       dtype='object')

# %%
Lstrade_heat = Lstrade.drop(['종목명','업종명','상장주식수대비월거래량합계_x','거래대금_x','벤치마크지수','소외주','거래소코드','회계년도','대비','거래대금_합계','years','month','LOW P/B'], axis=1)

# %%
LStrade_heat
# Out:
#                      EPS      PER      BPS      PBR  업종월평균PBR   상장시가총액  \
# EPS              1.00000 -0.26868  0.65916 -0.22029  -0.21514  0.00014
# PER             -0.26868  1.00000 -0.20992  0.09993   0.16781 -0.01062
# BPS              0.65916 -0.20992  1.00000 -0.51734  -0.28439  0.05443
# PBR             -0.22029  0.09993 -0.51734  1.00000   0.45927  0.16024
# 업종월평균PBR        -0.21514  0.16781 -0.28439  0.45927   1.00000  0.11235
# 상장시가총액           0.00014 -0.01062  0.05443  0.16024   0.11235  1.00000
# 총자본증가율(IFRS)     0.07448 -0.12939  0.06336  0.22014  -0.12028  0.07026
# 자기자본증가율(IFRS)    0.11831 -0.16481  0.12267  0.27690   0.03746  0.16957
# 매출액증가율(IFRS)     0.17323  0.01379  0.18154  0.13706  -0.10255  0.10418
# 순이익증가율(IFRS)    -0.08416 -0.01187 -0.06384 -0.03029  -0.06709  0.02089
# 매출액순이익률(IFRS)    0.18746 -0.02362  0.13891  0.08711   0.04433 -0.03877
# 총자본순이익률(IFRS)    0.08865 -0.22277  0.06621  0.42151   0.07163  0.14242
# ...

# %%
LStrade_heat = Lstrade_heat.astype(float)

# %%
Lstrade_heat.corr()
plt.figure(figsize=(25,20))
sns.heatmap(Lstrade_heat.corr(), linewidths = 0.1, vmax = 1.0,
           square = True, cmap = 'Blues', linecolor = "white", annot = True, annot_kws = {"size" : 16})
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>

# %%
LStrade_heat.replace(np.inf,np.nan)
# Out:
#                      EPS      PER      BPS      PBR  업종월평균PBR   상장시가총액  \
# EPS              1.00000 -0.26868  0.65916 -0.22029  -0.21514  0.00014
# PER             -0.26868  1.00000 -0.20992  0.09993   0.16781 -0.01062
# BPS              0.65916 -0.20992  1.00000 -0.51734  -0.28439  0.05443
# PBR             -0.22029  0.09993 -0.51734  1.00000   0.45927  0.16024
# 업종월평균PBR        -0.21514  0.16781 -0.28439  0.45927   1.00000  0.11235
# 상장시가총액           0.00014 -0.01062  0.05443  0.16024   0.11235  1.00000
# 총자본증가율(IFRS)     0.07448 -0.12939  0.06336  0.22014  -0.12028  0.07026
# 자기자본증가율(IFRS)    0.11831 -0.16481  0.12267  0.27690   0.03746  0.16957
# 매출액증가율(IFRS)     0.17323  0.01379  0.18154  0.13706  -0.10255  0.10418
# 순이익증가율(IFRS)    -0.08416 -0.01187 -0.06384 -0.03029  -0.06709  0.02089
# 매출액순이익률(IFRS)    0.18746 -0.02362  0.13891  0.08711   0.04433 -0.03877
# 총자본순이익률(IFRS)    0.08865 -0.22277  0.06621  0.42151   0.07163  0.14242
# ...

# %%
LStrade_heat.dropna(axis=0,inplace=True)

# %%
LStrade_heat = Lstrade_heat.corr()

# %%
LStrade_heat =LStrade_heat.astype(float)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

sns.pairplot(Lstrade_heat[['EPS', 'PBR', 'BPS', 'PER', '등락률']])
plt.show()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
X_train = Lstrade_heat[['EPS', 'PBR', 'BPS', 'PER', '등락률']]
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif['VIF_Factor'] = [variance_inflation_factor(X_train.values, i)
                         for i in range(X_train.shape[1])]
    vif['Feature'] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-128-1de71a7f206e> in <module>
#       6     vif['Feature'] = X_train.columns
#       7     return vif
# ----> 8 vif = feature_engineering_XbyVIF(X_train)
#       9 print(vif)
#
# <ipython-input-128-1de71a7f206e> in feature_engineering_XbyVIF(X_train)
#       2 def feature_engineering_XbyVIF(X_train):
#       3     vif = pd.DataFrame()
# ----> 4     vif['VIF_Factor'] = [variance_inflation_factor(X_train.values, i)
#       5                          for i in range(X_train.shape[1])]
#       6     vif['Feature'] = X_train.columns
#
# <ipython-input-128-1de71a7f206e> in <listcomp>(.0)
#       2 def feature_engineering_XbyVIF(X_train):
#       3     vif = pd.DataFrame()
# ----> 4     vif['VIF_Factor'] = [variance_inflation_factor(X_train.values, i)
#       5                          for i in range(X_train.shape[1])]
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

sns.pairplot(Lstrade_heat[['EPS', 'PBR', 'BPS', 'PER', '등락률']])
plt.show()
 
X_train = Lstrade_heat[['EPS', 'PBR', 'BPS', 'PER', '등락률']]
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif['VIF_Factor'] = [variance_inflation_factor(X_train.values, i)
                         for i in range(X_train.shape[1])]
    vif['Feature'] = X_train.columns
    return vif
vif = feature_engineering_XbyVIF(X_train)
print(vif)
 
Lstrade_heat['intercept'] = 1
model = sm.OLS(Lstrade_heat['등락률'], Lstrade_heat[['EPS', 'PBR', 'BPS', 'PER', '등락률']])
results = model.fit()
print(results.summary())
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-117-36821fcd74fe> in <module>
#      15     vif['Feature'] = X_train.columns
#      16     return vif
# ---> 17 vif = feature_engineering_XbyVIF(X_train)
#      18 print(vif)
#      19
#
# <ipython-input-117-36821fcd74fe> in feature_engineering_XbyVIF(X_train)
#      11 def feature_engineering_XbyVIF(X_train):
#      12     vif = pd.DataFrame()
# ---> 13     vif['VIF_Factor'] = [variance_inflation_factor(X_train.values, i)
# ...
