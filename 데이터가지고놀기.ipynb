# %%
import pandas as pd

# %%
df = pd.read_excel('./csv/15.xlsx')

# %%
idx = df[df['회계년도']=='Dec-16'].index

# %%
df = df.drop(idx)

# %%
df

# %%
import Tlqkf
import imp
imp.reload(Tlqkf)
# Out:
# <module 'Tlqkf' from 'c:\\Users\\LG\\OneDrive\\바탕 화면\\python\\프로젝트1\\Tlqkf.py'>

# %%
df
# Out:
#           회사명   거래소코드                 회계년도  총자본증가율  자기자본증가율  매출액증가율   순이익증가율  \
# 0     BNK금융지주  138930  2016-12-01 00:00:00   10.75    12.07   99.25  1093.17
# 1     BNK금융지주  138930  2017-12-01 00:00:00    1.04     0.94   42.36    72.59
# 2     BNK금융지주  138930  2018-12-01 00:00:00    3.62     3.93  -45.03   -77.84
# 3     BNK금융지주  138930  2019-12-01 00:00:00    0.69     3.47   57.09   214.98
# 4     BNK금융지주  138930  2020-12-01 00:00:00    4.04     4.25   94.22   173.33
# ...       ...     ...                  ...     ...      ...     ...      ...
# 4508     흥아해운    3280  2018-12-01 00:00:00   -6.15   -47.28   -9.71     0.00
# 4509     흥아해운    3280  2019-12-01 00:00:00  -50.62   -68.92  -86.19     0.00
# 4510     흥아해운    3280  2021-12-01 00:00:00  -12.91     0.00   -4.37     0.00
# 4511     흥아해운    3280  2020-12-01 00:00:00  -26.33     0.00  -12.24     0.00
# 4512     흥아해운    3280  2017-12-01 00:00:00  -11.51   -41.46    0.11     0.00
#
#       매출액순이익률  총자본순이익률  자기자본순이익률  ...  타인자본구성비율     부채비율  총자본회전률  자기자본회전률  \
# 0       58.27     1.38      1.75  ...     21.16    26.83    0.02     0.03
# 1       70.64     2.25      2.85  ...     21.23    26.96    0.03     0.04
# 2       28.48     0.49      0.62  ...     21.00    26.58    0.02     0.02
# 3       57.10     1.50      1.87  ...     18.81    23.17    0.03     0.03
# 4       80.36     4.01      4.93  ...     18.65    22.93    0.05     0.06
# ...       ...      ...       ...  ...       ...      ...     ...      ...
# 4508   -13.75   -11.99   -117.99  ...     92.75  1279.81    0.87     8.58
# 4509   -53.97    -8.99   -141.33  ...     95.44  2092.30    0.17     2.62
# 4510    19.30     5.92      0.00  ...     56.39   129.31    0.31     0.00
# 4511   -43.76   -11.14      0.00  ...    107.08     0.00    0.25     0.00
# 4512    -8.70    -7.65    -46.61  ...     87.10   675.08    0.88     5.36
#
#       자본금회전률  타인자본회전률    PER   PBR    PCR    PSR
# 0       0.09     0.11  32.80  0.55  28.55  19.11
# 1       0.11     0.15  21.09  0.61  14.40  14.90
# 2       0.06     0.08  81.73  0.51  81.59  23.27
# 3       0.10     0.13  22.60  0.43  67.80  12.91
# 4       0.19     0.27   4.64  0.23   4.54   3.73
# ...      ...      ...    ...   ...    ...    ...
# 4508    9.30     0.97   0.00  1.09   0.00   0.09
# 4509    1.35     0.18   0.00  1.93   0.00   0.35
# 4510    0.92     0.37   2.95  0.43   0.00   0.57
# 4511    1.49     0.25   0.00  0.00   0.00   0.27
# 4512   12.23     1.05   0.00  0.85   0.00   0.12
#
# [4513 rows x 26 columns]

# %%
from datetime import datetime

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4513 entries, 0 to 4512
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   회사명       4513 non-null   object
#  1   거래소코드     4513 non-null   int64
#  2   회계년도      4513 non-null   object
#  3   총자본증가율    4472 non-null   float64
#  4   자기자본증가율   4472 non-null   float64
#  5   매출액증가율    4472 non-null   float64
#  6   순이익증가율    4472 non-null   float64
#  7   매출액순이익률   4472 non-null   float64
#  8   총자본순이익률   4472 non-null   float64
#  9   자기자본순이익률  4472 non-null   float64
#  10  자본금순이익률   4472 non-null   float64
#  11  유보율       4472 non-null   float64
#  12  사내유보율     4472 non-null   float64
#  13  자기자본배당률   4472 non-null   float64
#  14  배당성향      4472 non-null   float64
#  15  자기자본구성비율  4472 non-null   float64
#  16  타인자본구성비율  4472 non-null   float64
#  17  부채비율      4472 non-null   float64
#  18  총자본회전률    4472 non-null   float64
#  19  자기자본회전률   4472 non-null   float64
#  20  자본금회전률    4472 non-null   float64
#  21  타인자본회전률   4472 non-null   float64
#  22  PER       4472 non-null   float64
#  23  PBR       4472 non-null   float64
#  24  PCR       4472 non-null   float64
#  25  PSR       4472 non-null   float64
# dtypes: float64(23), int64(1), object(2)
# memory usage: 952.0+ KB

# %%
df['회계년도'] = df['회계년도'].astype('str')

# %%
df['회계년도'] = pd.to_datetime(df['회계년도'])

# %%
df['회계년도'] = df['회계년도'].dt.year

# %%
df = df.set_index('회사명')

# %%
df =df.fillna(0)

# %%
df.drop(['거래소코드'],axis=1,inplace=True)

# %%
df_d = df.drop(['회계년도'],axis=1)

# %%
df_d.drop(['배당성향','타인자본구성비율','자본금회전률','총자본회전률','타인자본회전률'],axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# 거래소코드       0
# 회계년도        0
# 총자본증가율      0
# 자기자본증가율     0
# 매출액증가율      0
# 순이익증가율      0
# 매출액순이익률     0
# 총자본순이익률     0
# 자기자본순이익률    0
# 자본금순이익률     0
# 유보율         0
# 사내유보율       0
# 자기자본배당률     0
# 배당성향        0
# 자기자본구성비율    0
# 타인자본구성비율    0
# 부채비율        0
# 총자본회전률      0
# 자기자본회전률     0
# 자본금회전률      0
# 타인자본회전률     0
# PER         0
# PBR         0
# PCR         0
# PSR         0
# dtype: int64

# %%
df_p = pd.pivot_table(df, index='회사명', columns='회계년도')

# %%
df_p.isna().sum()
# Out:
#          회계년도
# PBR      2016    98
#          2017    61
#          2018    44
#          2019    31
#          2020    23
#                  ..
# 타인자본회전률  2017    61
#          2018    44
#          2019    31
#          2020    23
#          2021     0
# Length: 144, dtype: int64

# %%
df_p
# Out:
#             PBR                                  PCR                       \
# 회계년도       2016  2017  2018  2019  2020  2021   2016   2017   2018   2019
# 회사명
# AJ네트웍스     4.60  0.83  0.77  0.64  0.31  0.50   0.00   0.00   0.00   0.00
# BNK금융지주    0.55  0.61  0.51  0.43  0.23  0.35  28.55  14.40  81.59  67.80
# CS홀딩스      0.48  0.53  0.40  0.39  0.24  0.39   0.00  80.42  30.56  26.77
# DB금융투자     0.23  0.24  0.25  0.25  0.14  0.25   0.51   0.00   0.00   0.00
# DB손해보험     1.17  0.99  0.85  0.59  0.29  0.44   1.41   3.83   2.94   2.00
# ...         ...   ...   ...   ...   ...   ...    ...    ...    ...    ...
# 휴니드테크놀러지스  1.64  1.30  0.99  0.78  0.43  0.61   5.93   0.00   2.04   0.00
# 휴비스        0.69  0.71  0.67  0.57  0.25  0.65   7.17   3.50   5.35   0.00
# 휴스틸        0.24  0.26  0.19  0.19  0.08  0.09   0.00   0.00   0.74   5.50
# 흥국화재해상보험   0.41  0.38  0.42  0.29  0.13  0.29   0.22   0.23   0.30   0.24
# 흥아해운       0.62  0.85  1.09  1.93  0.00  0.43   0.00   0.00   0.00   0.00
#
#            ... 타인자본구성비율                       타인자본회전률                          \
# 회계년도       ...     2018   2019    2020   2021    2016  2017  2018  2019  2020
# 회사명        ...
# AJ네트웍스     ...    75.25  74.79   75.22  68.89    0.56  0.46  0.46  0.45  0.50
# BNK금융지주    ...    21.00  18.81   18.65  23.06    0.11  0.15  0.08  0.13  0.27
# CS홀딩스      ...     4.41   4.44    4.38   4.65    0.20  0.33  0.39  0.43  0.44
# DB금융투자     ...    88.32  90.00   90.82  88.34    0.27  0.18  0.15  0.16  0.21
# DB손해보험     ...    87.65  86.90   87.13  87.79    0.50  0.48  0.44  0.44  0.44
# ...        ...      ...    ...     ...    ...     ...   ...   ...   ...   ...
# 휴니드테크놀러지스  ...    52.22  55.61   52.37  50.18    2.29  3.33  3.33  1.48  1.43
# 휴비스        ...    57.03  55.02   46.10  43.82    2.23  2.36  2.33  1.86  1.83
# 휴스틸        ...    31.04  27.31   27.66  29.86    2.68  2.82  2.34  2.70  2.22
# 흥국화재해상보험   ...    94.29  94.37   94.52  94.98    0.48  0.42  0.38  0.37  0.37
# 흥아해운       ...    92.75  95.44  107.08  56.39    1.14  1.05  0.97  0.18  0.25
#
#
# 회계년도       2021
# 회사명
# AJ네트웍스     0.56
# BNK금융지주    0.20
# CS홀딩스      0.46
# DB금융투자     0.18
# DB손해보험     0.42
# ...         ...
# 휴니드테크놀러지스  1.72
# 휴비스        2.56
# 휴스틸        2.71
# 흥국화재해상보험   0.35
# 흥아해운       0.37
#
# [795 rows x 144 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font', family='Malgun Gothic')

# %%
df_d.corr()
plt.figure(figsize=(25,20))
sns.heatmap(df_d.astype(float).corr(), linewidths = 0.1, vmax = 1.0,
           square = True, cmap = 'Blues', linecolor = "white", annot = True, annot_kws = {"size" : 16})
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>
